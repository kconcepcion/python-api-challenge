# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy import stats
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#getting the url
weatherUrl = "http://api.openweathermap.org/data/2.5/weather?"
#setting the unit types to imperial (this is specifically being use for temperatures in Fahrenheit)
unitType = "imperial"

#bruilding partial query URL (missing the city specification)
queryUrl = f"{weatherUrl}appid={weather_api_key}&units={unitType}&q="

# %%
#testing the request url to see if it works
#also getting the keys name. this is so I can call them in the for loop below
weatherResponse = requests.get(queryUrl + city).json()
print(json.dumps(weatherResponse, indent=4))
# Out:
# {
#     "coord": {
#         "lon": -68.3,
#         "lat": -54.8
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 33.46,
#         "feels_like": 33.46,
#         "temp_min": 33.46,
#         "temp_max": 33.46,
#         "pressure": 1016,
#         "humidity": 93
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.3,
#         "deg": 360
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1659527165,
#     "sys": {
#         "type": 1,
#         "id": 8303,
#         "country": "AR",
#         "sunrise": 1659529117,
#         "sunset": 1659560404
#     },
#     "timezone": -10800,
#     "id": 3833367,
#     "name": "Ushuaia",
#     "cod": 200
# }

# %%
#creating the lists to hold the city info
cityName = []
cityCountry = []
cityDate = []
   ##in coord section
cityLat = []
cityLong = []
   ##in main section
cityTemp = []
cityHum = []
   ##in clouds section
cityCloud = []
   ##in wind section
cityWind = []

#creating a counter to print out the location
counter = 0

# %%
#printing out the start of the gathing data process to inform the user
print("Starting to gather the city data")
print("This data includes: Name, Country, Lat/Long, Temperature, Humidity, Cloudiness, and Wind Speed")
print(f"----------------------------------------------------------------------------------------------")

#using a for loop to traverse the city list and append the city to the queryUrl
#including a try and catch just in case the cities are not found
for city1 in cities:
    try:
        #creating the url request for each city
        cityResponse = requests.get(queryUrl + city1).json()
        
        #appending the current cities infomation to the list initialzed above
        cityLong.append(cityResponse["coord"]["lon"])
        cityLat.append(cityResponse["coord"]["lat"])
        cityTemp.append(cityResponse["main"]["temp_max"])
        cityHum.append(cityResponse["main"]["humidity"])
        cityWind.append(cityResponse["wind"]["speed"])
        cityCloud.append(cityResponse["clouds"]["all"])
        cityDate.append(cityResponse["dt"])
        cityCountry.append(cityResponse["sys"]["country"])
        
        #getting a new list of city names, this excludes the cities that were not found
        cityName.append(cityResponse["name"])
        counter += 1
        
        print(f"collecting data for city {city1}, city number: {counter}")
        
    except:
        print(f"{city1} was not found. Proceeding to the next city")

    continue
# Out:
# Starting to gather the city data
# This data includes: Name, Country, Lat/Long, Temperature, Humidity, Cloudiness, and Wind Speed
# ----------------------------------------------------------------------------------------------
# collecting data for city belyy yar, city number: 1
# collecting data for city bone, city number: 2
# collecting data for city ushuaia, city number: 3
# collecting data for city ribeira grande, city number: 4
# collecting data for city broome, city number: 5
# collecting data for city bluff, city number: 6
# collecting data for city busselton, city number: 7
# collecting data for city jawhar, city number: 8
# collecting data for city havoysund, city number: 9
# collecting data for city koshurnikovo, city number: 10
# collecting data for city hermanus, city number: 11
# amderma was not found. Proceeding to the next city
# collecting data for city rikitea, city number: 12
# collecting data for city beberibe, city number: 13
# collecting data for city xai-xai, city number: 14
# collecting data for city punta arenas, city number: 15
# collecting data for city tiksi, city number: 16
# collecting data for city kandrian, city number: 17
# collecting data for city san jose del palmar, city number: 18
# collecting data for city kavieng, city number: 19
# collecting data for city lompoc, city number: 20
# collecting data for city pisco, city number: 21
# collecting data for city marzuq, city number: 22
# collecting data for city nuuk, city number: 23
# collecting data for city guiyang, city number: 24
# collecting data for city arraial do cabo, city number: 25
# collecting data for city iskateley, city number: 26
# collecting data for city bandarbeyla, city number: 27
# collecting data for city mataura, city number: 28
# collecting data for city padang, city number: 29
# collecting data for city vaini, city number: 30
# collecting data for city cherskiy, city number: 31
# collecting data for city ambon, city number: 32
# collecting data for city bulawayo, city number: 33
# collecting data for city grindavik, city number: 34
# grand river south east was not found. Proceeding to the next city
# collecting data for city airai, city number: 35
# collecting data for city ulladulla, city number: 36
# collecting data for city quatre cocos, city number: 37
# collecting data for city saint-philippe, city number: 38
# collecting data for city norman wells, city number: 39
# collecting data for city vallenar, city number: 40
# collecting data for city ust-omchug, city number: 41
# collecting data for city sitka, city number: 42
# collecting data for city nikolskoye, city number: 43
# collecting data for city tuktoyaktuk, city number: 44
# inderborskiy was not found. Proceeding to the next city
# collecting data for city mao, city number: 45
# collecting data for city kiama, city number: 46
# collecting data for city avarua, city number: 47
# collecting data for city lima, city number: 48
# collecting data for city izberbash, city number: 49
# saleaula was not found. Proceeding to the next city
# collecting data for city port alfred, city number: 50
# collecting data for city cape town, city number: 51
# collecting data for city san matias, city number: 52
# collecting data for city togur, city number: 53
# collecting data for city lorengau, city number: 54
# collecting data for city olbia, city number: 55
# collecting data for city san patricio, city number: 56
# collecting data for city jamestown, city number: 57
# collecting data for city biak, city number: 58
# collecting data for city loiza, city number: 59
# collecting data for city hithadhoo, city number: 60
# collecting data for city melita, city number: 61
# collecting data for city kapaa, city number: 62
# collecting data for city kaitangata, city number: 63
# collecting data for city albany, city number: 64
# collecting data for city faya, city number: 65
# collecting data for city kamskiye polyany, city number: 66
# collecting data for city hualmay, city number: 67
# collecting data for city qesarya, city number: 68
# collecting data for city pirovskoye, city number: 69
# collecting data for city flinders, city number: 70
# collecting data for city mahebourg, city number: 71
# collecting data for city khatanga, city number: 72
# collecting data for city urdoma, city number: 73
# collecting data for city provideniya, city number: 74
# collecting data for city zalantun, city number: 75
# collecting data for city guaymas, city number: 76
# collecting data for city askino, city number: 77
# collecting data for city atuona, city number: 78
# collecting data for city solnechnyy, city number: 79
# collecting data for city neuquen, city number: 80
# collecting data for city hovd, city number: 81
# collecting data for city severo-kurilsk, city number: 82
# collecting data for city new norfolk, city number: 83
# collecting data for city meulaboh, city number: 84
# collecting data for city sao filipe, city number: 85
# collecting data for city mar del plata, city number: 86
# collecting data for city behat, city number: 87
# collecting data for city lebu, city number: 88
# collecting data for city hasaki, city number: 89
# sorvag was not found. Proceeding to the next city
# collecting data for city port blair, city number: 90
# collecting data for city saint-joseph, city number: 91
# collecting data for city dargaville, city number: 92
# collecting data for city mount gambier, city number: 93
# collecting data for city gornorechenskiy, city number: 94
# collecting data for city carnduff, city number: 95
# collecting data for city wucheng, city number: 96
# collecting data for city hobart, city number: 97
# collecting data for city tczew, city number: 98
# collecting data for city surt, city number: 99
# collecting data for city itarema, city number: 100
# collecting data for city zhucheng, city number: 101
# collecting data for city manaure, city number: 102
# collecting data for city katsuura, city number: 103
# collecting data for city valparaiso, city number: 104
# collecting data for city boca do acre, city number: 105
# collecting data for city goundam, city number: 106
# collecting data for city bengkulu, city number: 107
# collecting data for city cua, city number: 108
# collecting data for city cidreira, city number: 109
# collecting data for city sept-iles, city number: 110
# collecting data for city nome, city number: 111
# collecting data for city neftcala, city number: 112
# collecting data for city taoudenni, city number: 113
# collecting data for city aklavik, city number: 114
# collecting data for city loukhi, city number: 115
# collecting data for city castro, city number: 116
# collecting data for city leningradskiy, city number: 117
# collecting data for city cerrito, city number: 118
# collecting data for city songjianghe, city number: 119
# collecting data for city puerto ayora, city number: 120
# collecting data for city sao borja, city number: 121
# collecting data for city port elizabeth, city number: 122
# collecting data for city saskylakh, city number: 123
# collecting data for city vila velha, city number: 124
# collecting data for city kamareddi, city number: 125
# collecting data for city bethel, city number: 126
# sentyabrskiy was not found. Proceeding to the next city
# illoqqortoormiut was not found. Proceeding to the next city
# collecting data for city butaritari, city number: 127
# tumannyy was not found. Proceeding to the next city
# collecting data for city vao, city number: 128
# collecting data for city dire, city number: 129
# collecting data for city trapani, city number: 130
# collecting data for city mount isa, city number: 131
# collecting data for city qaanaaq, city number: 132
# collecting data for city dikson, city number: 133
# collecting data for city owando, city number: 134
# collecting data for city cap malheureux, city number: 135
# collecting data for city yellowknife, city number: 136
# collecting data for city phalombe, city number: 137
# collecting data for city fortuna, city number: 138
# tapaua was not found. Proceeding to the next city
# collecting data for city saldanha, city number: 139
# umzimvubu was not found. Proceeding to the next city
# collecting data for city portland, city number: 140
# collecting data for city sinegorye, city number: 141
# collecting data for city jishou, city number: 142
# collecting data for city mednogorsk, city number: 143
# collecting data for city east london, city number: 144
# collecting data for city yabrud, city number: 145
# collecting data for city thompson, city number: 146
# collecting data for city bambous virieux, city number: 147
# taolanaro was not found. Proceeding to the next city
# collecting data for city inongo, city number: 148
# collecting data for city obihiro, city number: 149
# collecting data for city bell ville, city number: 150
# collecting data for city bredasdorp, city number: 151
# collecting data for city port macquarie, city number: 152
# jomalig was not found. Proceeding to the next city
# ardistan was not found. Proceeding to the next city
# collecting data for city buala, city number: 153
# collecting data for city alta floresta, city number: 154
# collecting data for city carnarvon, city number: 155
# collecting data for city batagay, city number: 156
# attawapiskat was not found. Proceeding to the next city
# collecting data for city korla, city number: 157
# collecting data for city moshi, city number: 158
# collecting data for city codrington, city number: 159
# collecting data for city barrow, city number: 160
# collecting data for city okha, city number: 161
# collecting data for city eureka, city number: 162
# collecting data for city tura, city number: 163
# bolshaya chernigovka was not found. Proceeding to the next city
# collecting data for city tasiilaq, city number: 164
# collecting data for city juneau, city number: 165
# collecting data for city caravelas, city number: 166
# barawe was not found. Proceeding to the next city
# collecting data for city samana, city number: 167
# collecting data for city sola, city number: 168
# collecting data for city tucuman, city number: 169
# collecting data for city tevaitoa, city number: 170
# collecting data for city porto belo, city number: 171
# collecting data for city benguela, city number: 172
# collecting data for city lavrentiya, city number: 173
# collecting data for city havre-saint-pierre, city number: 174
# collecting data for city barstow, city number: 175
# collecting data for city almaznyy, city number: 176
# collecting data for city dudinka, city number: 177
# collecting data for city challapata, city number: 178
# collecting data for city abha, city number: 179
# collecting data for city ergani, city number: 180
# collecting data for city torbay, city number: 181
# collecting data for city pinheiro machado, city number: 182
# collecting data for city georgetown, city number: 183
# collecting data for city luderitz, city number: 184
# collecting data for city atikokan, city number: 185
# collecting data for city san cristobal, city number: 186
# collecting data for city liverpool, city number: 187
# collecting data for city edd, city number: 188
# collecting data for city geraldton, city number: 189
# collecting data for city guerrero negro, city number: 190
# collecting data for city nanortalik, city number: 191
# collecting data for city inuvik, city number: 192
# collecting data for city temir, city number: 193
# collecting data for city bathsheba, city number: 194
# collecting data for city saint george, city number: 195
# collecting data for city chuy, city number: 196
# collecting data for city fort nelson, city number: 197
# collecting data for city padilla, city number: 198
# collecting data for city santa maria, city number: 199
# collecting data for city ayan, city number: 200
# collecting data for city port-gentil, city number: 201
# collecting data for city puerto lopez, city number: 202
# collecting data for city zeya, city number: 203
# collecting data for city havelock, city number: 204
# collecting data for city bulgan, city number: 205
# collecting data for city belaya gora, city number: 206
# collecting data for city oistins, city number: 207
# collecting data for city port lincoln, city number: 208
# collecting data for city mayskiy, city number: 209
# collecting data for city mumford, city number: 210
# collecting data for city talcahuano, city number: 211
# collecting data for city taksimo, city number: 212
# collecting data for city temple, city number: 213
# collecting data for city yar-sale, city number: 214
# collecting data for city ancud, city number: 215
# collecting data for city crotone, city number: 216
# collecting data for city naze, city number: 217
# collecting data for city nalut, city number: 218
# collecting data for city barao de melgaco, city number: 219
# uzumlu was not found. Proceeding to the next city
# collecting data for city salvador, city number: 220
# collecting data for city puerto del rosario, city number: 221
# collecting data for city longyearbyen, city number: 222
# collecting data for city xichang, city number: 223
# collecting data for city cayenne, city number: 224
# collecting data for city srednekolymsk, city number: 225
# mullaitivu was not found. Proceeding to the next city
# collecting data for city varhaug, city number: 226
# collecting data for city shenjiamen, city number: 227
# collecting data for city chokurdakh, city number: 228
# collecting data for city sakaraha, city number: 229
# collecting data for city ukiah, city number: 230
# collecting data for city alice springs, city number: 231
# collecting data for city niono, city number: 232
# collecting data for city aswan, city number: 233
# nguiu was not found. Proceeding to the next city
# mys shmidta was not found. Proceeding to the next city
# collecting data for city bismarck, city number: 234
# collecting data for city klaksvik, city number: 235
# collecting data for city pokhara, city number: 236
# collecting data for city valleyview, city number: 237
# longlac was not found. Proceeding to the next city
# collecting data for city roald, city number: 238
# collecting data for city lagoa, city number: 239
# collecting data for city skibbereen, city number: 240
# collecting data for city shieli, city number: 241
# collecting data for city daoukro, city number: 242
# collecting data for city college, city number: 243
# kamenskoye was not found. Proceeding to the next city
# meyungs was not found. Proceeding to the next city
# galiwinku was not found. Proceeding to the next city
# collecting data for city phangnga, city number: 244
# nizhneyansk was not found. Proceeding to the next city
# collecting data for city kargat, city number: 245
# collecting data for city singkang, city number: 246
# collecting data for city rundu, city number: 247
# warqla was not found. Proceeding to the next city
# belushya guba was not found. Proceeding to the next city
# collecting data for city batticaloa, city number: 248
# collecting data for city fare, city number: 249
# burica was not found. Proceeding to the next city
# collecting data for city kisangani, city number: 250
# collecting data for city souillac, city number: 251
# vaitupu was not found. Proceeding to the next city
# collecting data for city porto nacional, city number: 252
# collecting data for city likasi, city number: 253
# collecting data for city hilo, city number: 254
# collecting data for city iqaluit, city number: 255
# collecting data for city dragalina, city number: 256
# collecting data for city husavik, city number: 257
# collecting data for city tongchuan, city number: 258
# collecting data for city bandar-e lengeh, city number: 259
# collecting data for city umbita, city number: 260
# collecting data for city beringovskiy, city number: 261
# collecting data for city kutum, city number: 262
# collecting data for city homer, city number: 263
# collecting data for city badarpur, city number: 264
# collecting data for city male, city number: 265
# collecting data for city delemont, city number: 266
# collecting data for city rantoul, city number: 267
# collecting data for city dingle, city number: 268
# collecting data for city isiolo, city number: 269
# collecting data for city esperance, city number: 270
# collecting data for city pevek, city number: 271
# collecting data for city zunyi, city number: 272
# collecting data for city tuatapere, city number: 273
# collecting data for city lata, city number: 274
# collecting data for city zhangjiakou, city number: 275
# collecting data for city barkhan, city number: 276
# collecting data for city mordovo, city number: 277
# mahadday weyne was not found. Proceeding to the next city
# collecting data for city joshimath, city number: 278
# collecting data for city vila franca do campo, city number: 279
# collecting data for city kruisfontein, city number: 280
# collecting data for city victoria, city number: 281
# collecting data for city bubaque, city number: 282
# collecting data for city novikovo, city number: 283
# collecting data for city placido de castro, city number: 284
# collecting data for city pattani, city number: 285
# palabuhanratu was not found. Proceeding to the next city
# collecting data for city upernavik, city number: 286
# collecting data for city nha trang, city number: 287
# collecting data for city ampanihy, city number: 288
# collecting data for city meadow lake, city number: 289
# collecting data for city pangnirtung, city number: 290
# collecting data for city vaitape, city number: 291
# collecting data for city sobolevo, city number: 292
# collecting data for city egvekinot, city number: 293
# collecting data for city labytnangi, city number: 294
# collecting data for city stornoway, city number: 295
# collecting data for city semnan, city number: 296
# samusu was not found. Proceeding to the next city
# collecting data for city goderich, city number: 297
# collecting data for city sur, city number: 298
# collecting data for city plettenberg bay, city number: 299
# collecting data for city bandar-e anzali, city number: 300
# collecting data for city manavalakurichi, city number: 301
# collecting data for city ciudad bolivar, city number: 302
# collecting data for city providencia, city number: 303
# collecting data for city haines junction, city number: 304
# viligili was not found. Proceeding to the next city
# collecting data for city dormidontovka, city number: 305
# collecting data for city kavaratti, city number: 306
# collecting data for city nouadhibou, city number: 307
# collecting data for city grindsted, city number: 308
# skiros was not found. Proceeding to the next city
# collecting data for city beloha, city number: 309
# collecting data for city plymouth, city number: 310
# collecting data for city cairns, city number: 311
# collecting data for city parana, city number: 312
# collecting data for city beidao, city number: 313
# collecting data for city isangel, city number: 314
# collecting data for city porbandar, city number: 315
# collecting data for city hambantota, city number: 316
# tsihombe was not found. Proceeding to the next city
# collecting data for city benghazi, city number: 317
# collecting data for city san quintin, city number: 318
# collecting data for city ahuimanu, city number: 319
# collecting data for city ulaangom, city number: 320
# collecting data for city banda aceh, city number: 321
# collecting data for city corrente, city number: 322
# mutsamudu was not found. Proceeding to the next city
# collecting data for city afonino, city number: 323
# collecting data for city tabou, city number: 324
# collecting data for city maine-soroa, city number: 325
# collecting data for city ponta do sol, city number: 326
# collecting data for city harper, city number: 327
# collecting data for city frederikshavn, city number: 328
# collecting data for city leh, city number: 329
# collecting data for city safita, city number: 330
# collecting data for city huarmey, city number: 331
# collecting data for city ducheng, city number: 332
# collecting data for city la huaca, city number: 333
# collecting data for city sarakhs, city number: 334
# collecting data for city lobez, city number: 335
# collecting data for city karabash, city number: 336
# collecting data for city ferrol, city number: 337
# collecting data for city chase, city number: 338
# collecting data for city oberriet, city number: 339
# collecting data for city bonavista, city number: 340
# collecting data for city saint-pierre, city number: 341
# collecting data for city vulcan, city number: 342
# collecting data for city touros, city number: 343
# collecting data for city roma, city number: 344
# collecting data for city qaqortoq, city number: 345
# collecting data for city isla mujeres, city number: 346
# collecting data for city kuytun, city number: 347
# collecting data for city lasa, city number: 348
# collecting data for city necochea, city number: 349
# collecting data for city kachiry, city number: 350
# collecting data for city kenai, city number: 351
# collecting data for city andenes, city number: 352
# collecting data for city marawi, city number: 353
# collecting data for city cacule, city number: 354
# collecting data for city huntingdon, city number: 355
# collecting data for city longyan, city number: 356
# collecting data for city baker city, city number: 357
# collecting data for city tanout, city number: 358
# collecting data for city waipawa, city number: 359
# collecting data for city pahalgam, city number: 360
# collecting data for city pyu, city number: 361
# collecting data for city waverly, city number: 362
# collecting data for city washougal, city number: 363
# collecting data for city morant bay, city number: 364
# collecting data for city garissa, city number: 365
# collecting data for city kahului, city number: 366
# collecting data for city ganzhou, city number: 367
# ruatoria was not found. Proceeding to the next city
# collecting data for city kholodnyy, city number: 368
# collecting data for city delmas, city number: 369
# collecting data for city mahon, city number: 370
# collecting data for city la ronge, city number: 371
# bolungarvik was not found. Proceeding to the next city
# collecting data for city hofn, city number: 372
# collecting data for city jeremie, city number: 373
# collecting data for city hay river, city number: 374
# collecting data for city sisimiut, city number: 375
# collecting data for city salalah, city number: 376
# barentsburg was not found. Proceeding to the next city
# collecting data for city kalmunai, city number: 377
# collecting data for city ingham, city number: 378
# collecting data for city aksarka, city number: 379
# collecting data for city ilulissat, city number: 380
# collecting data for city slave lake, city number: 381
# collecting data for city ginda, city number: 382
# collecting data for city makakilo city, city number: 383
# collecting data for city clyde river, city number: 384
# collecting data for city tongzi, city number: 385
# collecting data for city francisco beltrao, city number: 386
# collecting data for city fairbanks, city number: 387
# collecting data for city acarau, city number: 388
# collecting data for city camana, city number: 389
# collecting data for city turukhansk, city number: 390
# collecting data for city baltati, city number: 391
# collecting data for city svetlaya, city number: 392
# collecting data for city oranjemund, city number: 393
# collecting data for city chapleau, city number: 394
# collecting data for city imeni babushkina, city number: 395
# collecting data for city sibolga, city number: 396
# collecting data for city iturama, city number: 397
# collecting data for city ostrovnoy, city number: 398
# collecting data for city mahe, city number: 399
# collecting data for city faanui, city number: 400
# chelyabinsk-40 was not found. Proceeding to the next city
# collecting data for city erenhot, city number: 401
# collecting data for city yanam, city number: 402
# collecting data for city saint marys, city number: 403
# collecting data for city araouane, city number: 404
# collecting data for city vibo valentia, city number: 405
# collecting data for city kindu, city number: 406
# collecting data for city acapulco, city number: 407
# collecting data for city namibe, city number: 408
# collecting data for city chake chake, city number: 409
# collecting data for city ambilobe, city number: 410
# collecting data for city kodiak, city number: 411
# collecting data for city jaguaribe, city number: 412
# collecting data for city zyryanka, city number: 413
# collecting data for city maniitsoq, city number: 414
# collecting data for city iralaya, city number: 415
# collecting data for city sungaipenuh, city number: 416
# collecting data for city farah, city number: 417
# collecting data for city montichiari, city number: 418
# collecting data for city constitucion, city number: 419
# collecting data for city kulhudhuffushi, city number: 420
# collecting data for city cabo san lucas, city number: 421
# collecting data for city ishinomaki, city number: 422
# collecting data for city dalby, city number: 423
# collecting data for city dunedin, city number: 424
# collecting data for city los llanos de aridane, city number: 425
# collecting data for city leo, city number: 426
# collecting data for city bhayavadar, city number: 427
# collecting data for city muisne, city number: 428
# collecting data for city viedma, city number: 429
# collecting data for city umm lajj, city number: 430
# collecting data for city grand-lahou, city number: 431
# collecting data for city sabang, city number: 432
# collecting data for city vyritsa, city number: 433
# collecting data for city salinopolis, city number: 434
# collecting data for city rawson, city number: 435
# collecting data for city bela, city number: 436
# collecting data for city northam, city number: 437
# collecting data for city petrolina, city number: 438
# collecting data for city harrisonburg, city number: 439
# collecting data for city mahanoro, city number: 440
# collecting data for city jacqueville, city number: 441
# collecting data for city udachnyy, city number: 442
# collecting data for city arlit, city number: 443
# collecting data for city grand island, city number: 444
# collecting data for city anchorage, city number: 445
# collecting data for city teguise, city number: 446
# collecting data for city keita, city number: 447
# collecting data for city camacha, city number: 448
# collecting data for city alofi, city number: 449
# tabialan was not found. Proceeding to the next city
# collecting data for city vanimo, city number: 450
# collecting data for city benjamin aceval, city number: 451
# collecting data for city monrovia, city number: 452
# collecting data for city hargeysa, city number: 453
# collecting data for city saint-augustin, city number: 454
# collecting data for city urucara, city number: 455
# halalo was not found. Proceeding to the next city
# collecting data for city andros, city number: 456
# collecting data for city kampene, city number: 457
# collecting data for city mecca, city number: 458
# collecting data for city muroto, city number: 459
# collecting data for city thurso, city number: 460
# collecting data for city imeni poliny osipenko, city number: 461
# collecting data for city batagay-alyta, city number: 462
# collecting data for city carutapera, city number: 463
# collecting data for city dundalk, city number: 464
# collecting data for city mantua, city number: 465
# collecting data for city upington, city number: 466
# collecting data for city rio grande, city number: 467
# collecting data for city pomabamba, city number: 468
# collecting data for city shingu, city number: 469
# collecting data for city mapiripan, city number: 470
# collecting data for city dwarka, city number: 471
# collecting data for city atchison, city number: 472
# collecting data for city chapais, city number: 473
# collecting data for city dunda, city number: 474
# collecting data for city tomari, city number: 475
# collecting data for city macaubas, city number: 476
# collecting data for city ballina, city number: 477
# collecting data for city oktyabrskiy, city number: 478
# collecting data for city vyshkov, city number: 479
# collecting data for city iaciara, city number: 480
# collecting data for city green river, city number: 481
# collecting data for city broken hill, city number: 482
# saint quentin was not found. Proceeding to the next city
# collecting data for city moron, city number: 483
# collecting data for city balikpapan, city number: 484
# collecting data for city kristiinankaupunki, city number: 485
# collecting data for city sinnamary, city number: 486
# collecting data for city iracoubo, city number: 487
# collecting data for city sioux lookout, city number: 488
# collecting data for city saryg-sep, city number: 489
# haibowan was not found. Proceeding to the next city
# collecting data for city ligayan, city number: 490
# collecting data for city ushtobe, city number: 491
# collecting data for city ketchikan, city number: 492
# collecting data for city gorbehaza, city number: 493
# collecting data for city tombouctou, city number: 494
# collecting data for city dubbo, city number: 495
# collecting data for city teahupoo, city number: 496
# collecting data for city mondovi, city number: 497
# collecting data for city ayios vasilios, city number: 498
# collecting data for city kroya, city number: 499
# collecting data for city cilegon, city number: 500
# collecting data for city sheridan, city number: 501
# collecting data for city deputatskiy, city number: 502
# collecting data for city boa vista, city number: 503
# collecting data for city chancay, city number: 504
# collecting data for city kirensk, city number: 505
# collecting data for city carol stream, city number: 506
# collecting data for city cheyenne, city number: 507
# collecting data for city severnyy, city number: 508
# collecting data for city atasu, city number: 509
# tabiauea was not found. Proceeding to the next city
# gazni was not found. Proceeding to the next city
# collecting data for city jalu, city number: 510
# collecting data for city aykhal, city number: 511
# collecting data for city oytal, city number: 512
# collecting data for city qidong, city number: 513
# collecting data for city shimoda, city number: 514
# collecting data for city bardstown, city number: 515
# collecting data for city panama city, city number: 516
# collecting data for city sines, city number: 517
# collecting data for city kem, city number: 518
# collecting data for city ipira, city number: 519
# collecting data for city bakchar, city number: 520
# collecting data for city soyo, city number: 521
# collecting data for city cockburn town, city number: 522
# collecting data for city iglino, city number: 523
# collecting data for city tolaga bay, city number: 524
# collecting data for city arman, city number: 525
# collecting data for city port hardy, city number: 526
# collecting data for city fort wellington, city number: 527
# collecting data for city eyemouth, city number: 528
# collecting data for city capoterra, city number: 529
# collecting data for city nueva gorgona, city number: 530
# collecting data for city sungairaya, city number: 531
# collecting data for city morondava, city number: 532
# collecting data for city half moon bay, city number: 533
# collecting data for city veraval, city number: 534
# collecting data for city willowmore, city number: 535
# collecting data for city antalaha, city number: 536
# collecting data for city kapoeta, city number: 537
# collecting data for city ayorou, city number: 538
# collecting data for city kailua, city number: 539
# collecting data for city agadez, city number: 540
# collecting data for city catuday, city number: 541
# tunxi was not found. Proceeding to the next city
# collecting data for city biskamzha, city number: 542
# collecting data for city sao joao da barra, city number: 543
# collecting data for city okhotsk, city number: 544
# collecting data for city lar, city number: 545
# yomitan was not found. Proceeding to the next city
# collecting data for city nicoya, city number: 546
# collecting data for city outjo, city number: 547
# collecting data for city ahipara, city number: 548
# collecting data for city tubmanburg, city number: 549
# skagastrond was not found. Proceeding to the next city
# collecting data for city sandakan, city number: 550
# collecting data for city gimli, city number: 551
# collecting data for city khandyga, city number: 552
# collecting data for city berezovka, city number: 553
# collecting data for city duncan, city number: 554
# collecting data for city mabaruma, city number: 555
# collecting data for city bereda, city number: 556
# rungata was not found. Proceeding to the next city
# collecting data for city portel, city number: 557
# collecting data for city manor, city number: 558
# collecting data for city mandera, city number: 559
# collecting data for city hidalgo, city number: 560
# collecting data for city rio gallegos, city number: 561
# collecting data for city durazno, city number: 562
# collecting data for city poum, city number: 563
# collecting data for city kurbnesh, city number: 564
# collecting data for city fort smith, city number: 565
# collecting data for city namatanai, city number: 566
# chagda was not found. Proceeding to the next city
# collecting data for city wawa, city number: 567
# collecting data for city skibotn, city number: 568
# collecting data for city talnakh, city number: 569
# collecting data for city marsa matruh, city number: 570
# collecting data for city grand gaube, city number: 571
# collecting data for city vadso, city number: 572
# collecting data for city minab, city number: 573
# collecting data for city melilla, city number: 574
# collecting data for city palmer, city number: 575
# collecting data for city chipinge, city number: 576
# collecting data for city tautira, city number: 577
# collecting data for city san pedro, city number: 578
# collecting data for city darhan, city number: 579
# collecting data for city port hawkesbury, city number: 580
# collecting data for city river falls, city number: 581

# %%
print("------------------------")
print("    Data collected!")
print("------------------------")
# Out:
# ------------------------
#     Data collected!
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#compiling all lists into one dataframe
weatherData = {"City Name": cityName,
    "Country Code": cityCountry,
    "City Data": cityDate,
    "City Latitude": cityLat,
    "City Longitude": cityLong,
    "City Temperature": cityTemp,
    "City Humidity": cityHum,
    "City Cloudiness": cityCloud,
    "City Wind Speed": cityWind}

#converting into dataframe
weatherDF = pd.DataFrame(weatherData)

# %%
#printing out the weather dataframe
weatherDF.head(100)
# Out:
#          City Name Country Code   City Data  City Latitude  City Longitude  \
# 0        Belyy Yar           RU  1659527165        53.6039         91.3903
# 1             Bone           DE  1659527166        51.9669         12.1396
# 2          Ushuaia           AR  1659527165       -54.8000        -68.3000
# 3   Ribeira Grande           PT  1659527166        38.5167        -28.7000
# 4           Broome           US  1659527142        42.2506        -75.8330
# ..             ...          ...         ...            ...             ...
# 95         Wucheng           CN  1659527205        29.6008        118.1750
# 96          Hobart           AU  1659527205       -42.8794        147.3294
# 97           Tczew           PL  1659527206        54.0924         18.7779
# 98           Sirte           LY  1659527206        31.2089         16.5887
# 99         Itarema           BR  1659527207        -2.9248        -39.9167
#
#     City Temperature  City Humidity  City Cloudiness  City Wind Speed
# 0              68.86             56                0             8.95
# 1              91.81             27               53             4.59
# 2              33.46             93               40             2.30
# 3              79.20             89               40             9.22
# 4              64.54             90                0             1.99
# ..               ...            ...              ...              ...
# 95             84.36             74               53             1.07
# 96             54.27             77               20             4.61
# 97             85.64            100                8            10.02
# 98             85.12             57                0            10.67
# 99             80.73             70               71            14.85
#
# [100 rows x 9 columns]

# %%
#exporting the datafame into a csv file

#setting the location of the file
output_data_file = "output_data/cities.csv"

#exporting the df to the file listed above, with the name listed above
weatherDF.to_csv(output_data_file)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#creating a new df where the cities with humidities are greater than 100

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#plotting the latitude v temperature plot

#plotting the base scatterplot with plt
plt.scatter(cityLat, cityTemp, marker="o", facecolors="blue", edgecolors="black")

#creating a title, x label, and y label for the chart
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature (Fahrenheit)")
plt.grid(True)

#giving a little description of what the scatterplot is showing
print("This scatter plot below is showing the temperature across the earth's latitude.")

#exporting the scatterplot to a png and saving it in the data_export file
plt.savefig("output_data/LatitudeVTemperaturePlot.png")
# Out:
# This scatter plot below is showing the temperature across the earth's latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#plotting the latitude v humidity plot

#plotting the base scatterplot with plt
plt.scatter(cityLat, cityHum, marker="o", facecolors="red", edgecolors="black")

#creating a title, x label, and y label for the chart
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid(True)

#giving a little description of what the scatterplot is showing
print("This scatter plot below is showing the humidity across the earth's latitude.")

#exporting the scatterplot to a png and saving it in the output_data file
plt.savefig("output_data/LatitudeVHumidityPlot.png")
# Out:
# This scatter plot below is showing the humidity across the earth's latitude.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#plotting the latitude v cloudiness plot

#plotting the base scatterplot with plt
plt.scatter(cityLat, cityCloud, marker="o", facecolors="orange", edgecolors="black")

#creating a title, x label, and y label for the chart
plt.title("Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid(True)

#giving a little description of what the scatterplot is showing
print("This scatter plot below is showing the cloudiness across the earth's latitude.")

#exporting the scatterplot to a png and saving it in the data_export file
plt.savefig("output_data/LatitudeVCloudinessPlot.png")
# Out:
# This scatter plot below is showing the cloudiness across the earth's latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#plotting the latitude v wind speed plot

#plotting the base scatterplot with plt
plt.scatter(cityLat, cityWind, marker="o", facecolors="green", edgecolors="black")

#creating a title, x label, and y label for the chart
plt.title("Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph) ")
plt.grid(True)

#giving a little description of what the scatterplot is showing
print("This scatter plot below is showing the wind speed across the earth's latitude.")

#exporting the scatterplot to a png and saving it in the data_export file
plt.savefig("output_data/LatitudeVWindSpeedPlot.png")
# Out:
# This scatter plot below is showing the wind speed across the earth's latitude.

# %% [markdown]
# ## Linear Regression

# %%
#first im creating two dataframes to make the northen/southern hemisphere plots from 
#using the .loc function on the dataframe I created
northDF = weatherDF.loc[weatherDF["City Latitude"] >= 0.0]
northDF.reset_index(inplace=True)

southDF = weatherDF.loc[weatherDF["City Latitude"] < 0.0]
southDF.reset_index(inplace=True)

# %%
#defining the def plotLinearRegression function to create a generic plot to reference back to for each of the required plots
#this will make it easier to compute each equation, instead of writing out the equation with new variable names each time

#adding the table's x and y value, title, x and y labels and equation position
def plotLinearRegression(xVal,yVal,plotTitle,xLabel,yLabel,labelPos,plotFig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xVal, yVal)
    #printing the r value for each scatter plot
    print(f"The r value is: {rvalue}")
    regressVal = xVal * slope + intercept
    lineEquation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(xVal,yVal,marker="o", facecolors="violet", edgecolors="black")
    plt.plot(xVal,regressVal,"r-")
    plt.annotate(lineEquation,labelPos,fontsize=15,color="red")
    plt.title(plotTitle)
    plt.xlabel(xLabel)
    plt.ylabel(yLabel)
    plt.savefig(f"output_data/fig{plotFig}.png")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#norther hemisphere max temp v latitude with linear regression
plotTitle = "Northern Max Temp vs. Latitude Linear Regression (Date: 8/3/22)"
xLabel = "Latitude"
yLabel = "Max Temperature (Fahrenheit)"
labelPos = (0, 50)
plotLinearRegression(northDF["City Latitude"], northDF["City Temperature"],plotTitle, xLabel, yLabel, labelPos, 1)
# Out:
# The r-squared is: -0.6198934370487792

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#southern hemisphere max temp v latitude with linear regression
plotTitle = "Southern Max Temp vs. Latitude Linear Regression (Date: 8/3/22)"
xLabel = "Latitude"
yLabel = "Max Temperature (Fahrenheit)"
labelPos = (-55, 80)
plotLinearRegression(southDF["City Latitude"], southDF["City Temperature"],plotTitle, xLabel, yLabel, labelPos, 2)
# Out:
# The r-squared is: 0.7738075539974036

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#norther hemisphere humidity v latitude with linear regression
plotTitle = "Northern Humidity vs. Latitude Linear Regression (Date: 8/3/22)"
xLabel = "Latitude"
yLabel = "Humidity (%)"
labelPos = (45, 20)
plotLinearRegression(northDF["City Latitude"], northDF["City Humidity"],plotTitle, xLabel, yLabel, labelPos, 3)
# Out:
# The r-squared is: 0.022514795834375115

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#southern hemisphere humidity v latitude with linear regression
plotTitle = "Southern Humidity vs. Latitude Linear Regression (Date: 8/3/22)"
xLabel = "Latitude"
yLabel = "Humidity (%)"
labelPos = (-55, 20)
plotLinearRegression(southDF["City Latitude"], southDF["City Humidity"],plotTitle, xLabel, yLabel, labelPos, 4)
# Out:
# The r-squared is: -0.2213732756329871

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#northern hemisphere cloudiness v latitude with linear regression
plotTitle = "Northern Cloudiness vs. Latitude Linear Regression (Date: 8/3/22)"
xLabel = "Latitude"
yLabel = "Cloudiness"
labelPos = (0, 20)
plotLinearRegression(northDF["City Latitude"], northDF["City Cloudiness"],plotTitle, xLabel, yLabel, labelPos, 5)
# Out:
# The r-squared is: -0.04377161462935303

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#southern hemisphere cloudiness v latitude with linear regression
plotTitle = "Southern Cloudiness vs. Latitude Linear Regression (Date: 8/3/22)"
xLabel = "Latitude"
yLabel = "Cloudiness"
labelPos = (-55, 20)
plotLinearRegression(southDF["City Latitude"], southDF["City Cloudiness"],plotTitle, xLabel, yLabel, labelPos, 6)
# Out:
# The r-squared is: 0.0742319811051361

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#northern hemisphere wind speed v latitude with linear regression
plotTitle = "Northern Wind Speed vs. Latitude Linear Regression (Date: 8/3/22)"
xLabel = "Latitude"
yLabel = "Wind Speed"
labelPos = (0, 25)
plotLinearRegression(northDF["City Latitude"], northDF["City Wind Speed"],plotTitle, xLabel, yLabel, labelPos, 7)
# Out:
# The r-squared is: -0.024350472376669062

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Southern hemisphere Wind Speed v latitude with linear regression
plotTitle = "Southern Wind Speed vs. Latitude Linear Regression (Date: 8/3/22)"
xLabel = "Latitude"
yLabel = "Wind Speed"
labelPos = (-55, 30)
plotLinearRegression(southDF["City Latitude"], southDF["City Wind Speed"],plotTitle, xLabel, yLabel, labelPos, 8)
# Out:
# The r-squared is: 0.04964255981275227
